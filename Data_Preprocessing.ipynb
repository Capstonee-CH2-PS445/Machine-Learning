# %%
import pandas as pd
from google.colab import files
import numpy as np
filenya = files.upload()
# Out:
#      <input type="file" id="files-2c367d18-b15a-4f81-9d64-d25b63bd96e7" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-2c367d18-b15a-4f81-9d64-d25b63bd96e7">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
books = pd.read_csv('Buku - Buku Rekomendasi(1) (1).csv')
books.head()
# Out:
#                                            Title_URL  \
# 0  https://www.bukukita.com/Ekonomi-dan-Manajemen...
# 1  https://www.bukukita.com/Sejarah-dan-Budaya/Se...
# 2  https://www.bukukita.com/Ekonomi-dan-Manajemen...
# 3  https://www.bukukita.com/Psikologi-dan-Pengemb...
# 4  https://www.bukukita.com/Ekonomi-dan-Manajemen...
#
#                                                Image  \
# 0  https://www.bukukita.com/babacms/displaybuku/1...
# 1  https://www.bukukita.com/babacms/displaybuku/1...
# 2  https://www.bukukita.com/babacms/displaybuku/1...
# 3  https://www.bukukita.com/babacms/displaybuku/1...
# 4  https://www.bukukita.com/babacms/displaybuku/1...
#
#                                                Judul  \
# 0  DESIGN THINKING FOR BUSINESS GROWTH (Cara Berp...
# 1  Origins : Bagaimana Sejarah Bumi Membentuk Sej...
# 2  Richer, Wiser, Happier: Bagaimana Investor Ter...
# 3                  The Kremlin School Of Negotiation
# ...

# %%
books.columns
# Out:
# Index(['Title_URL', 'Image', 'Judul', 'Penulis', 'ISBN', 'Penerbit',
#        'Terbitan', 'Kategori', 'Deskripsi'],
#       dtype='object')

# %%
new_books = books.drop(['Title_URL', 'Image'], axis=1)
new_books.head()
# Out:
#                                                Judul  \
# 0  DESIGN THINKING FOR BUSINESS GROWTH (Cara Berp...
# 1  Origins : Bagaimana Sejarah Bumi Membentuk Sej...
# 2  Richer, Wiser, Happier: Bagaimana Investor Ter...
# 3                  The Kremlin School Of Negotiation
# 4  Online Advertising Summary : Rangkuman Tips Be...
#
#                                              Penulis           ISBN  \
# 0  \n\t\t\t\t\t\t\t\t\t\t\tMICHAEL LEWRICK, PATRI...  9786230048906
# 1  \n\t\t\t\t\t\t\t\t\t\t\tLewis Dartnell\t\t\t\t...  9786232201491
# 2  \n\t\t\t\t\t\t\t\t\t\t\tWilliam Green\t\t\t\t\...  9786230047503
# 3  \n\t\t\t\t\t\t\t\t\t\t\tIgor Ryzov\t\t\t\t\t\t...  9786238036059
# 4  \n\t\t\t\t\t\t\t\t\t\t\tTim The Conversion\t\t...              -
#
#                  Penerbit      Terbitan          Kategori  \
# 0  Elex Media Komputindo    Juli - 2023  Bisnis-Investasi
# 1                Alvabet    Juni - 2023     Sejarah Dunia
# ...

# %%
new_books['Penulis'] = new_books['Penulis'].str.replace('\n', '').str.replace('\t', '').str.strip()
new_books['Deskripsi'] = new_books['Deskripsi'].str.replace('\n', '').str.replace('\t', '').str.strip()
new_books['Deskripsi'] = new_books['Deskripsi'].str.replace('DESCRIPTION', '')
new_books.head()
# Out:
#                                                Judul  \
# 0  DESIGN THINKING FOR BUSINESS GROWTH (Cara Berp...
# 1  Origins : Bagaimana Sejarah Bumi Membentuk Sej...
# 2  Richer, Wiser, Happier: Bagaimana Investor Ter...
# 3                  The Kremlin School Of Negotiation
# 4  Online Advertising Summary : Rangkuman Tips Be...
#
#                                        Penulis           ISBN  \
# 0  MICHAEL LEWRICK, PATRICK LINK, LARRY LEIFER  9786230048906
# 1                               Lewis Dartnell  9786232201491
# 2                                William Green  9786230047503
# 3                                   Igor Ryzov  9786238036059
# 4                           Tim The Conversion              -
#
#                  Penerbit      Terbitan          Kategori  \
# 0  Elex Media Komputindo    Juli - 2023  Bisnis-Investasi
# 1                Alvabet    Juni - 2023     Sejarah Dunia
# 2  Elex Media Komputindo     Mei - 2023  Bisnis-Investasi
# ...

# %%
new_books.isnull().sum()
# Out:
# Judul        2
# Penulis      1
# ISBN         1
# Penerbit     2
# Terbitan     1
# Kategori     2
# Deskripsi    1
# dtype: int64

# %%
new_books[new_books.isnull().any(axis=1)]
# Out:
#      Judul Penulis ISBN Penerbit Terbitan Kategori Deskripsi
# 832    NaN     NaN  NaN      NaN      NaN      NaN       NaN
# 1262   NaN           mm      NaN        -      NaN

# %%
new_books_cleaned = new_books.dropna()
new_books_cleaned.isnull().sum()
# Out:
# Judul        0
# Penulis      0
# ISBN         0
# Penerbit     0
# Terbitan     0
# Kategori     0
# Deskripsi    0
# dtype: int64

# %%
new_books_cleaned[new_books_cleaned['ISBN'] == '-']
# Out:
#                                                   Judul  \
# 4     Online Advertising Summary : Rangkuman Tips Be...
# 5     Buku Trilogy of Inspirations Hermanto Tanoko R...
# 14                                    Connect The Dots
# 91            Komik Seri : Hai, Miiko! 33 Edisi Khusus
# 101                     Resep Sehat JSR (Edisi Terbaru)
# ...                                                 ...
# 2088              Belajar Sendiri: Membuat Robot Cerdas
# 2095                                           The Diet
# 2132  The Secret Life of Bees - Kehidupan Rahasia Lebah
# 2134           The Voices of Demons (Suara-suara Iblis)
# 2137  Si Cacing dan Kotoran Kesayangannya (Revisi da...
#
#                                                 Penulis ISBN  \
# 4                                    Tim The Conversion    -
# 5     Belinda Natalia Tanoko, Johan Alvin Khosuma & ...    -
# 14                                          HELMY YAHYA    -
# ...

# %%
new_books_cleaned[new_books_cleaned['Judul'] == '-']
# Out:
# Empty DataFrame
# Columns: [Judul, Penulis, ISBN, Penerbit, Terbitan, Kategori, Deskripsi]
# Index: []

# %%
new_books_cleaned[new_books_cleaned['Penulis'] == '-']
# Out:
# Empty DataFrame
# Columns: [Judul, Penulis, ISBN, Penerbit, Terbitan, Kategori, Deskripsi]
# Index: []

# %%
new_books_cleaned[new_books_cleaned['Penerbit'] == '-']
# Out:
# Empty DataFrame
# Columns: [Judul, Penulis, ISBN, Penerbit, Terbitan, Kategori, Deskripsi]
# Index: []

# %%
new_books_cleaned[new_books_cleaned['Terbitan'] == '-']
# Out:
#                                 Judul                         Penulis ISBN  \
# 2138  Rasa Sakit adalah suatu Karunia  DR. Paul Brand & Philip Yancey  979
#
#             Penerbit Terbitan Kategori Deskripsi
# 2138  Penguin group         -  Kristen

# %%
new_books_cleaned[new_books_cleaned['Kategori'] == '-']
# Out:
# Empty DataFrame
# Columns: [Judul, Penulis, ISBN, Penerbit, Terbitan, Kategori, Deskripsi]
# Index: []

# %%
new_books_cleaned[new_books_cleaned['Deskripsi'] == '-']
# Out:
# Empty DataFrame
# Columns: [Judul, Penulis, ISBN, Penerbit, Terbitan, Kategori, Deskripsi]
# Index: []

# %%
new_books_cleaned.isna().sum()
# Out:
# Judul        0
# Penulis      0
# ISBN         0
# Penerbit     0
# Terbitan     0
# Kategori     0
# Deskripsi    0
# dtype: int64

# %%
new_books_cleaned.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 2145 entries, 0 to 2146
# Data columns (total 7 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Judul      2145 non-null   object
#  1   Penulis    2145 non-null   object
#  2   ISBN       2145 non-null   object
#  3   Penerbit   2145 non-null   object
#  4   Terbitan   2145 non-null   object
#  5   Kategori   2145 non-null   object
#  6   Deskripsi  2145 non-null   object
# dtypes: object(7)
# memory usage: 134.1+ KB

# %%
books_fix = new_books_cleaned.replace({'ISBN': {'-': np.nan}, 'Terbitan': {'-': np.nan}})
books_fix[books_fix['ISBN'] == '-']
# Out:
# Empty DataFrame
# Columns: [Judul, Penulis, ISBN, Penerbit, Terbitan, Kategori, Deskripsi]
# Index: []

# %%
books_fix[books_fix['Terbitan'] == '-']
# Out:
# Empty DataFrame
# Columns: [Judul, Penulis, ISBN, Penerbit, Terbitan, Kategori, Deskripsi]
# Index: []

# %%
new_books_cleaned.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 2145 entries, 0 to 2146
# Data columns (total 7 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Judul      2145 non-null   object
#  1   Penulis    2145 non-null   object
#  2   ISBN       2145 non-null   object
#  3   Penerbit   2145 non-null   object
#  4   Terbitan   2145 non-null   object
#  5   Kategori   2145 non-null   object
#  6   Deskripsi  2145 non-null   object
# dtypes: object(7)
# memory usage: 134.1+ KB

# %%
books_fix.isnull().sum()
# Out:
# Judul          0
# Penulis        0
# ISBN         267
# Penerbit       0
# Terbitan       1
# Kategori       0
# Deskripsi      0
# dtype: int64

# %%
print(books_fix)
# Out:
#                                                   Judul  \
# 0     DESIGN THINKING FOR BUSINESS GROWTH (Cara Berp...
# 1     Origins : Bagaimana Sejarah Bumi Membentuk Sej...
# 2     Richer, Wiser, Happier: Bagaimana Investor Ter...
# 3                     The Kremlin School Of Negotiation
# 4     Online Advertising Summary : Rangkuman Tips Be...
# ...                                                 ...
# 2142                                       Mak Comblang
# 2143                            Dosa-Dosa Media Amerika
# 2144  Biografi Dan Brown : The Man Behind The Da Vin...
# 2145   Direktori Pasar Agrobisnis Dalam dan Luar Negeri
# 2146  Flowers for Algernon : Charlie Si Jenius Dungu...
#
#                                           Penulis           ISBN  \
# 0     MICHAEL LEWRICK, PATRICK LINK, LARRY LEIFER  9786230048906
# 1                                  Lewis Dartnell  9786232201491
# 2                                   William Green  9786230047503
# ...

# %%
books_fix.to_csv('books_fix.csv', index=False)
